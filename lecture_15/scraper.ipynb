# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://ss.ge/ka/udzravi-qoneba/l/bina/iyideba?MunicipalityId=95&CityIdList=95&StatusField.FieldId=34&StatusField.Type=SingleSelect&StatusField.StandardField=Status&PriceType=false&CurrencyId=1"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup.body
# Out:
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-K8CV4K4" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <div id="fb-root"></div>
# <!--full screen loader-->
# <div class="LoaderBlock" id="LoaderBlock" style="display:none;">
# <div class="LoaderElement"></div>
# </div>
# <!--full screen loader-->
# <div class="AllBodyBl">
# <div class="listing-header">
# <header class="DesktopHeader" id="header_block">
# <div class="topHeader">
# <div class="container">
# <div class="topHdrContainer">
# <div class="logo_left" style="">
# <a href="/"><img alt="" src="/img/Newlogo.svg?dtt"/></a>
# </div>
# <div>
# <ul class="nav_menu c-nav-menu">
# <li>
# <a class="nav-item active-home" href="/ka/udzravi-qoneba">
# <img src="/img/home-title.svg" width="20">
#                 უძრავი ქონება
#             </img></a>
# </li>
# <li>
# <a class="nav-item" href="/ka/auto">
# <img src="/img/cars-title.svg" width="28"/>
#                 ავტო
#             </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/sales">
# <img src="/img/cart-title.svg" width="20"/>
#                 მარკეტი
#             </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/jobs">
# <img src="/img/jobs-title.svg" width="19"/>
#                 დასაქმება
#             </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/jobs/list?IsEducation=True&amp;JobsDealTypeId=8">
# <img src="/img/edu-title.svg" width="19"/>
#                 განათლება
#             </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/services">
# <img src="/img/services-title.svg" width="18"/>
#                 მომსახურება
#             </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/finance">
# <img src="/img/icons/finance-icon.svg" width="18"/>
#                 ფინანსები
#             </a>
# </li>
# </ul>
# </div>
# <div class="topHeaderRight">
# <div class="headerButtons">
# <div class="add_article show-create-edit-info">
# <a href="/ka/home/createeditinfo">
# <button> განცხადების განთავსება</button>
# </a>
# </div>
# <div class="add_article hide-create-edit">
# <a href="/ka/udzravi-qoneba/create?Length=10">
# <button data-url="/ka/udzravi-qoneba/create?Length=10" id="add_item_but">განთავსება</button>
# </a>
# </div>
# </div>
# <div class="chat-start-hdr" data-target="#LoginRegisterModal" data-toggle="modal">
# <img alt="Alternate Text" src="/img/icons/hdr-msg-icon.svg"/>
# </div>
# <div class="login_form">
# <a class="login-btn" data-target="#LoginRegisterModal" data-toggle="modal">
# <img alt="Alternate Text" src="/img/user-icon.svg">
# <button id="login_but" type="button">შესვლა</button>
# </img></a>
# </div>
# <div class="language_switcher">
# <ul class="langBar dropdown" data-url="/ka/home/setlanguage" id="languageBar" name="lang">
# <li class="active dropdown-toggle" data-toggle="dropdown"><a disabled=""><img alt="Alternate Text" src="/img/geo.svg"/></a></li>
# <ul class="dropdown-menu">
# <li class="selectedLang" data-language="ka" data-rubric="udzravi-qoneba" style="display:none"><a class="lang_1" data-rubric="udzravi-qoneba" hidden="" lang="ka"><img alt="Alternate Text" src="/img/geo.svg"/><span>GEO</span></a></li>
# <li data-language="en" data-rubric="real-estate"><a class="lang_2" data-rubric="real-estate" lang="en"><img alt="Alternate Text" src="/img/eng.svg"/> <span>ENG</span></a></li>
# <li data-language="ru" data-rubric="недвижимость"><a class="lang_3" data-rubric="недвижимость" lang="ru"><img alt="Alternate Text" src="/img/rus.svg"/><span>RUS</span></a></li>
# </ul>
# </ul>
# </div>
# <input id="CurrencyTitle" type="hidden" value="აირჩიეთ ვალუტა"/>
# </div>
# </div>
# </div>
# </div>
# <div class="container" style="display: none;">
# <div class="header_row_top">
# <div class="logo_left">
# <a href="/"><img alt="" class="img-responsive" src="/img/Newlogo.svg?dtt"/></a>
# </div>
# <div class="header_row_bottom">
# <div class="header_row_bottom_in">
# <div class="headerButtons">
# <div class="add_article">
# <a href="/ka/udzravi-qoneba/create?Length=10">
# <button data-url="/ka/udzravi-qoneba/create?Length=10" id="add_item_but">განცხადების განთავსება</button>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="modal fade" id="FillBalanceModal" role="dialog">
# <div class="modal-dialog SuperVipModalDialog userIsNotActive">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button"></button>
# </div>
# <div class="modal-body">
# <div class="FillBalanceModalBody">
# <div class="FillBalanceEachblock">
# <div class="FillBalanceText">
#                             თქვენი ანგარიში დაბლოკილია ადმინისტრაციის მიერ. დამატებითი ინფორმაციის მისაღებად ან გასაჩივრებისათვის მოგვწერეთ მეილზე: info@ss.ge
#                         </div>
# <div class="FillBalanceText">
# <div class="notFoundAdsBtn">
# <a href="/">მთავარ გვერდზე დაბრუნება</a>
# </div>
# </div>
# <div class="cls"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="modal-dialog SuperVipModalDialog userIsActive modal-new" style="display: block">
# <div class="modal-content modal-balance-new">
# <div class="modal-header">
# <div class="header-balance">
#                     ბალანსის შევსება
#                 </div>
# <a class="close-btn" data-dismiss="modal" type="button">
# <img alt="Alternate Text" src="/img/x (2).svg">
# </img></a>
# </div>
# <div class="modal-body">
# <div class="FillBalanceModalBody">
# <div class="FillBalanceEachblock">
# <div class="text-imgs">
# <p class="FillBalanceInfoCash">
#                                 გთხოვთ მიუთითოთ თანხა
#                             </p>
# <div class="pay-visa-master">
# <img alt="Alternate Text" class="visa-img" src="/img/visa (2).svg"/>
# <img alt="Alternate Text" src="/img/master card.svg"/>
# </div>
# </div>
# <div class="FillBalanceInputGroup">
# <input class="price-inpt" id="inputCash" name="inputCash" placeholder=" მინიმალური შესატანი 3 ლარი" type="number"/>
# <span class="price-check-span hidden">მინიმალური შენატანია 3 ლარი</span>
# <span class="price-check-span-1 hidden">გთხოვთ სწორად შეიყვანოთ თანხა</span>
# <button class="balance-btn" data-url="/ka/user/updatebalance" id="update-balance">გაგრძელება</button>
# </div>
# </div>
# <div class="cls"></div>
# </div>
# </div>
# <div class="modal-footer">
# <div class="footer-content">
# <div class="TitLeBottomBalacne">ბალანსის შევსება ასევე შესაძლებელია: სწრაფი გადახდის აპარატებით</div>
# <div class="BalanceFillBlocks">
# <img alt="Alternate Text" class="margin-right-15" src="/img/tbc pay.svg"/>
# <img alt="Alternate Text" class="margin-right-15" src="/img/pay box.svg"/>
# <img alt="Alternate Text" class="margin-right-15" src="/img/e pay.svg"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script src="/js/user/fill-balance.js?v=1TN2WsOkNP4v4lT30b49_4ogabL9cxa46AoAI6L2_4A"></script>
# </div>
# <div class="MobileOverLaybg" id="MobileOverLaybgID"></div>
# <div class="MobileHeader">
# <div class="MobileHeader_in">
# <div class="overlay" id="myNav">
# <a class="closebtn searchCloseBtn" href="javascript:void(0)" onclick="closeNav_search()">×</a>
# <div class="overlay-content">
# <div class="search_group" data-base-url="/ka/udzravi-qoneba/l?Length=10" data-partial-url="/ka/udzravi-qoneba/realestateapplicationlist?Length=10" data-url="/ka/udzravi-qoneba/l?Length=10" id="searchRealEstate">
# <div id="imaginary_container">
# <div class="input-group stylish-input-group input-append">
# <input class="form-control" data-tooltip="true" data-val="true" data-val-required="The StringValues field is required." id="mobQuery" name="Context.Request.Query[Query]" placeholder="იპოვეთ სიტყვით,ტელეფონით, ID..." title="შეიყვანეთ მინიმუმ 3 სიმბოლო" type="text" value=""/>
# <span class="input-group-addon">
# <button id="query-button" onclick="openNav_search()" type="button">
# <span class="glyphicon glyphicon-search" title="ძიება"></span>
# </button>
# </span>
# </div>
# </div>
# </div>
# </div>
# <div class="loader-container">
# <?xml version="1.0" encoding="utf-8" ?>
# <svg baseprofile="tiny" class="loader hide" id="mobile_search_loader" version="1.2" viewbox="0 0 200 200" x="0" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" y="0"><path class="loaderreverse" d="M200 100c0-30.3-13.5-57.5-34.8-75.8 -4.8-4.1-12.2-3-15.8 2.3v0c-3 4.5-2.4 10.7 1.8 14.2 16.6 14.4 27.1 35.6 27.1 59.3s-10.5 44.9-27.1 59.3c-4.1 3.6-4.8 9.7-1.8 14.2v0c3.6 5.3 11 6.4 15.8 2.3C186.5 157.5 200 130.3 200 100z"></path><path d="M156.7 100c0-14.9-5.8-28.5-15.2-38.6 -4.6-4.9-12.6-4.1-16.3 1.4l-0.4 0.6c-2.8 4.1-2.2 9.5 1.2 13.2 5.7 6.2 9.1 14.4 9.1 23.5 0 9-3.4 17.3-9.1 23.5 -3.3 3.7-3.9 9-1.2 13.2l0.4 0.6c3.7 5.6 11.7 6.3 16.3 1.4C150.9 128.5 156.7 114.9 156.7 100z"></path></svg>
# </div>
# </div>
# <div class="MobileLogo">
# <a href="/"><img alt="" src="/img/Newlogo.svg?dtt" style="width: 101px!important"/></a>
# </div>
# <div class="rightBlockMobile">
# <div class="chat-start-hdr" data-target="#LoginRegisterModal" data-toggle="modal">
# <img alt="Alternate Text" src="/img/icons/hdr-msg-icon.svg"/>
# <div class="show-unread-Msg">2</div>
# </div>
# <div class="search_mobile" style="margin-right:38px;">
# <a onclick="openNav_search()"><img alt="" src="/img/search_mobile.png"/></a>
# </div>
# <div class="menu_burger">
# <div class="menu_burger_in">
# <a class="OpenNavBtn" onclick="openNav()">
# <div style="padding-right:10px;margin-top:7px;font-size:17px">მენიუ</div>
# <img alt="" src="/img/burger.png"/>
# </a>
# </div>
# <div class="cls"></div>
# </div>
# </div>
# <div class="cls"></div>
# <div class="sidenav" id="mySidenav">
# <ul class="add_article mob-header-add show-create-edit-info">
# <li class="login_form not-logged-btn"><a class="side_1" href="/ka/home/createeditinfo">განცხადების განთავსება</a></li>
# </ul>
# <ul class="add_article mob-header-add hide-create-edit">
# <li class="login_form not-logged-btn"><a class="side_1 btn-log-resp" data-target="#LoginRegisterModal" data-toggle="modal" data-url="/ka/udzravi-qoneba/create?Length=10">განცხადების განთავსება</a></li>
# </ul>
# <a class="closebtn CloseNavBtn" href="javascript:void(0)" onclick="closeNav()"></a>
# <div class="cls"></div>
# <div class="mob_side_menu">
# <ul class="MainListSide">
# <li class="login_form"><a class="side_1" data-target="#LoginRegisterModal" data-toggle="modal" href="/ka/user/login">შესვლა</a></li>
# <li>
# </li>
# <li class="mob-line"></li>
# <ul class="MenuDropOtherCats">
# <li><a href="/ka/udzravi-qoneba">უძრავი ქონება</a></li>
# <li><a href="/ka/auto">ავტო</a></li>
# <li style="position: relative"><a href="/ka/sales">მარკეტი</a> <span class="new-icon" style="top: 4px;left: 60px;">new</span></li>
# <li><a href="/ka/jobs">დასაქმება</a></li>
# <li><a href="/ka/jobs/list?IsEducation=True&amp;JobsDealTypeId=8">განათლება</a></li>
# <li><a href="/ka/services">მომსახურება</a></li>
# <li><a href="/ka/finance">ფინანსები</a></li>
# </ul>
#
# <li class="mob-line"></li>
# </ul>
# <div class="language_mob_box">
# <div><a class="side_3 support-btn" href="/ka/home/help">დახმარება</a></div>
# <ul data-url="/ka/home/setlanguage" id="lang" name="lang">
# <li class="lang_mob_logo"> </li>
# <li><a class="lang_1" data-rubric="udzravi-qoneba" disabled=")" lang="ka">GEO</a></li>
# <li><a =)="" class="lang_2" data-rubric="real-estate" lang="en">ENG</a></li>
# <li><a =)="" class="lang_3" data-rubric="недвижимость" lang="ru">RUS</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="cls"></div>
# <div class="mob-categories">
# <ul class="nav_menu c-nav-menu">
# <li>
# <a class="nav-item active-home" href="/ka/udzravi-qoneba">
# <img src="/img/home-title.svg" width="20"/>
#                     უძრავი ქონება
#                 </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/auto">
# <img src="/img/cars-title.svg" width="28"/>
#                     ავტო
#                 </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/sales">
# <img src="/img/cart-title.svg" width="20"/>
#                     მარკეტი
#                 </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/jobs">
# <img src="/img/jobs-title.svg" width="19"/>
#                     დასაქმება
#                 </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/jobs/list?IsEducation=True&amp;JobsDealTypeId=8">
# <img src="/img/edu-title.svg" width="19"/>
#                     განათლება
#                 </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/services">
# <img src="/img/services-title.svg" width="18"/>
#                     მომსახურება
#                 </a>
# </li>
# <li>
# <a class="nav-item" href="/ka/finance">
# <img src="/img/icons/finance-icon.svg" width="18"/>
#                     ფინანსები
#                 </a>
# </li>
# </ul>
# </div>
# </div>
# <div id="main-body">
# <div class="AllBodyBlBackDrop"></div>
# <style>
#     .EachSaswrafodImage {
#         height: 142px !important;
#     }
#
#     #top_suggestions {
#         margin-top: 20px;
#     }
#
#     .succ-overlay {
#         width: 100%;
#         height: 100%;
#         position: absolute;
#         left: 0;
#         top: 0;
#         background: rgba(0,0,0,0.5);
#         z-index: 9999;
#         display: none;
#     }
#
#     .latest_articles_head {
#         order: 2;
#     }
#
#     .articles_page_head_filter {
#         order: 2;
#     }
#
#     #subscribe_post {
#         display: block;
#     }
#
#     .RealEstateFilter .navigation_filters_block_in {
#         padding: 14px 0;
#     }
#
#     .subscribe_post_box {
#         display: block;
#     }
#
#     .articles_page_head {
#         margin-bottom: 20px;
#         padding-bottom: 0;
#     }
#
#     .latest_articles_head {
#         font-family: 'FiraGOR';
#         font-size: 13px;
#         font-weight: 500;
#         letter-spacing: 0.1px;
#         padding-bottom: 0 !important;
#         color: #4d4d4d;
#     }
#
#     #latest_articles {
#         margin-top: 0;
#     }
#
#         #latest_articles .latest_articles_block {
#             padding-right: 10px;
#         }
#
#     #nav_filters {
#         margin-bottom: 0px;
#         height: auto;
#         min-height: unset;
#     }
#
#
#     #subscribe_post {
#         order: 2;
#     }
#
#     /*.banner_h1 {
#         margin: 15px 0;
#     }*/
#     @media (max-width:760px) {
#         .choose_currency {
#             display: none !important;
#         }
#
#         #subscribe_post {
#             order: 1;
#         }
#
#         .articles_page_head {
#             flex-direction: column;
#         }
#
#         .subscribe_post {
#             justify-content: space-evenly;
#         }
#
#         #subscribe_post_modal .modal-content {
#             height: auto;
#             margin: 0 30px;
#         }
#
#             #subscribe_post_modal .modal-content form {
#                 flex-direction: column;
#             }
#
#             #subscribe_post_modal .modal-content form {
#                 width: auto;
#             }
#
#                 #subscribe_post_modal .modal-content form .form_item {
#                     width: 100%;
#                     text-align: center;
#                     margin: 10px 0 !important;
#                 }
#
#         .articles_page_head_filter {
#             padding: 20px 20px 0 20px;
#             flex-direction: row-reverse;
#             width: 100%;
#             justify-content: space-between;
#         }
#
#             .articles_page_head_filter .PriceChecsRg {
#                 margin-right: 0;
#             }
#
#         .latest_articles_head {
#             width: 100%;
#             text-align: left;
#             padding: 20px;
#         }
#
#         #nav_filters {
#             /*padding: 0 20px;*/
#             margin-bottom: 0;
#         }
#
#         .SAveFilterButton {
#             padding-right: 0 !important;
#         }
#
#         .articles_page_head {
#             margin-top: 0 !important;
#         }
#
#         #subscribe_post {
#             width: 100%;
#         }
#
#         .subscribe_post {
#             width: 100%;
#         }
#
#         footer {
#             margin: 0;
#         }
#     }
# </style>
# <div class="container">
# <section id="banner_b2_block">
# <div class="container">
# <div class="banner_b2_left" id="H1Listing-banner">
# <div id="adoceanadvertlinegelbepemiokt"></div> <script type="text/javascript"> /* (c)AdOcean 2003-2018, Advertline.http:saqme.ge.Saqme zones.H1 */ ado.slave('adoceanadvertlinegelbepemiokt', {myMaster: '6zdBGedMvBfJ5dFfwvGwvPT.UbNdcSeO8fUdjIkG2RL.17' }); </script>
# </div>
# </div>
# </section>
# </div>
# <div class="listing-mob-filter"> <div class="MobileFilterTopSrollButton">
# <div class="realEstateListFilMObToggle ListFilMObToggle">
# <!--Mobile Filter Toggle-->
# <div class="MobileFilterToggle RealEstateLisFilter">
# <div class="MobileFilterToggle_in">
# <div class="FilterToggleText">
#                     ფილტრი
#                 </div>
# </div>
# </div>
# <!--end Mobile Filter Toggle-->
# </div>
# </div>
# <div class="navigation_filters_block_in MobileFilterBgK" id="mobile-filter-navigation">
# <div class="filtmobText">
# <div class="mobile_filter_overlay"></div>
# <img alt="Alternate Text" class="hdr-main-banner" src="" style="display: none;"/>
# <div class="banner-link sim">
# <a href="https://house.ge/" target="_blank">
# <div class="hs-logo"><img alt="Alternate Text" src="/img/house_logo 1.svg"/></div>
# <div class="main-banner-title" style="margin-left: 30px">
#                     ყველა ახალი და მშენებარე ბინა  <img alt="Alternate Text" src="/img/arrowBanner.svg"/>
# </div>
# </a>
# </div>
# <div class="banner-link kvr">
# <a href="https://bit.ly/2QsQc5U" target="_blank">
# <div class=""><img alt="Alternate Text" src="/img/krwanisilogo.svg"/></div>
# <div class="main-banner-title" style="margin-left: 30px">
#                     ისუნთქე, იცხოვრე, დაისვენე <img alt="Alternate Text" src="/img/arrowBanner.svg"/>
# </div>
# </a>
# </div>
# <div style="z-index: 1">იპოვე შენთვის საუკეთესო</div>
# </div>
# <!--mobile filter-->
# <div class="FilterMobileMode">
# <div class="FilterMobileMode_in">
# <div class="MobFiltBody">
# <div class="MobFiltBody_in">
# <div class="FilterItemEAchmb MobFilterCat5" data-typeid="5">
# <div class="FilterItemEAchmb_in">
# <div class="FilterInTextI">
#                                         ბინა
#                                     </div>
# </div>
# </div>
# <div class="FilterItemEAchmb MobFilterCat4" data-typeid="4">
# <div class="FilterItemEAchmb_in">
# <div class="FilterInTextI">
#                                         კერძო სახლი
#                                     </div>
# </div>
# </div>
# <div class="FilterItemEAchmb MobFilterCat6" data-typeid="6">
# <div class="FilterItemEAchmb_in">
# <div class="FilterInTextI">
#                                         კომერციული
#                                     </div>
# </div>
# </div>
# <div class="FilterItemEAchmb MobFilterCat3" data-typeid="3">
# <div class="FilterItemEAchmb_in">
# <div class="FilterInTextI">
#                                         მიწის ნაკვეთი
#                                     </div>
# </div>
# </div>
# <div class="FilterItemEAchmb MobFilterCat1" data-typeid="1">
# <div class="FilterItemEAchmb_in">
# <div class="FilterInTextI">
#                                         აგარაკი
#                                     </div>
# </div>
# </div>
# <div class="FilterItemEAchmb MobFilterCat2" data-typeid="2">
# <div class="FilterItemEAchmb_in">
# <div class="FilterInTextI">
#                                         სასტუმრო
#                                     </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="cls"></div>
# </div>
# <div class="cls"></div>
# <!--PopUp MobFilter-->
# <div class="modal" id="MobileFilterMod" role="dialog">
# <div class="modal-dialog">
# <div class="modal-content">
# <button class="close closeModalfilter" data-dismiss="modal" type="button"></button>
# <div class="modal-body">
# <div class="MobileToggleFilterModal">
# <div class="MobileFilterToggle_in">
# <div class="FilterToggleText">
#                             ფილტრი
#                         </div>
# <div class="CloseModalXBut"> </div>
# </div>
# </div>
# <div id="mobile-filter-container"></div>
# </div>
# </div>
# </div>
# </div>
# <!--end PopUp MobFilter-->
# </div>
# <div class="RealEstateFilter listing-filter" data-rubricname="realestate">
# <div class="container filter-container" id="fltr-cont">
# <div class="filter-hdr">
# <div class="title">ფილტრი</div>
# <div class="map-switcher">
# <span class="map-title">რუკა</span>
# <label class="switch">
# <input checked="" class="map-list" type="checkbox"/>
# <span class="slider round"></span>
# </label>
# </div>
# <div class="close-map-btn"><img alt="Alternate Text" src="/img/closemap.svg"/></div>
# </div>
# <form autocomplete="off" class="filter-line" data-autosearch="True" data-filter-rubric="RealEstate" data-mapurl="/ka/realestate/getmapapplication" data-partial-url="/ka/udzravi-qoneba/realestateapplicationlist" data-url="/ka/udzravi-qoneba/l" id="nav_filters">
# <input constant="true" name="BaseUrl" type="hidden" value="/ka/udzravi-qoneba/l"/>
# <input constant="true" id="CurrentUserId" name="CurrentUserId" type="hidden" value=""/>
# <input constant="true" id="searchQ" name="Query" type="hidden" value=""/>
# <input id="MunicipalityId" name="MunicipalityId" type="hidden" value="95">
# <input id="CityId" name="CityIdList" type="hidden" value="95"/>
# <input id="RoomsCount" type="hidden" value=""/>
# <input data-val="true" data-val-required="The IsMap field is required." id="IsMap" name="IsMap" type="hidden" value="false">
# <input id="subdistr" name="subdistr" type="hidden" value=""/>
# <input id="stId" name="stId" type="hidden" value=""/>
# <input constant="true" id="PrcSource" name="PrcSource" type="hidden" value="1"/>
# <div class="NavFixes_Wrapper">
# <div class="navigation_filters_block">
# <div class="recent_search desk-recent-search" style="display: none">
#                         ბოლო ძიება:
#                         <div class="saved-filder-container"></div>
# </div>
# <div class="navigation_filters_block_rel">
# <div class="navigation_filters_block_in">
# <!--desktop Filter-->
# <div class="realestateBlockIn FilterDesktopMode">
# <div class="FilterTopBlock">
# <div class="RealEstateTypeId realEstateTypeBtn" data-title="ქონების ტიპი">
# <span> ქონების ტიპი</span>
# </div>
# <div class="filter_window realestate_window">
# <div class="mobile_titles">
# <h3>ქონების ტიპი</h3>
# <button class="closeWindow" type="button"></button>
# </div>
# <div class="window_inner">
# <div>
# <div class="RealEstateType">
# <div class="item">
# <input checked="checked" class="realestatetypeSelect" id="Flat" name="RealEstateTypeId" seo="bina" title="ბინა" type="radio" value="5">
# <label for="Flat">ბინა</label>
# </input></div>
# <div class="item">
# <input class="realestatetypeSelect" id="Private House" name="RealEstateTypeId" seo="kerdzo-saxli" title="კერძო სახლი" type="radio" value="4">
# <label for="Private House">კერძო სახლი</label>
# </input></div>
# <div class="item">
# <input class="realestatetypeSelect" id="Commercial Real Estate" name="RealEstateTypeId" seo="komerciuli" title="კომერციული" type="radio" value="6">
# <label for="Commercial Real Estate">კომერციული</label>
# </input></div>
# <div class="item">
# <input class="realestatetypeSelect" id="Land" name="RealEstateTypeId" seo="mitsis-nakveti" title="მიწის ნაკვეთი" type="radio" value="3">
# <label for="Land">მიწის ნაკვეთი</label>
# </input></div>
# <div class="item">
# <input class="realestatetypeSelect" id="Summer cottage" name="RealEstateTypeId" seo="agaraki" title="აგარაკი" type="radio" value="1">
# <label for="Summer cottage">აგარაკი</label>
# </input></div>
# <div class="item">
# <input class="realestatetypeSelect" id="Hotel" name="RealEstateTypeId" seo="sastumro" title="სასტუმრო" type="radio" value="2">
# <label for="Hotel">სასტუმრო</label>
# </input></div>
# </div>
# <div class="statusBlock" style="display: none">
# <h3>სტატუსი</h3>
# <div class="RealEstateStatus" data-url="/ka/realestate/getstatusfield"></div>
# </div>
# </div>
# <div class="controls">
# <button class="clear" type="button">გასუფთავება</button>
# <button class="save" type="button">შენახვა</button>
# </div>
# </div>
# </div>
# <div class="RealEstateDealTypeId">
# <div class="RealEstateDealTypeId realEstateDealTypeIdBtn" data-title="გარიგების ტიპი">
# <span> გარიგების ტიპი</span>
# </div>
# <input id="RealEstateDealTypeId" name="RealEstateDealTypeId" type="hidden" value="4">
# <div class="filter_window realestate-dealtype">
# <div class="mobile_titles">
# <button class="closeWindow" type="button"></button>
# </div>
# <div class="window_inner">
# <ul class="realEstateDealTypeList">
# <li data-seo="" data-value="" title="">გარიგების ტიპი</li>
# <li data-seo="iyideba" data-value="4" title="იყიდება">იყიდება</li>
# <li data-seo="qiravdeba" data-value="1" title="ქირავდება">ქირავდება</li>
# <li data-seo="giravdeba" data-value="2" title="გირავდება">გირავდება</li>
# <li data-seo="qiravdeba-dghiurad" data-value="3" title="ქირავდება დღიურად">ქირავდება დღიურად</li>
# </ul>
# </div>
# </div>
# </input></div>
# <div class="FartChangeInpGroupblock address-list">
# <div class="ListFiltTitleBk locationMultiSelect">
# <span class="default-value">მდებარეობა</span>
# <span class="selectedText">
# <span class="cityText"></span>
# <span class="subDistrText"></span>
# <span class="strText"></span>
# </span>
# <img alt="Alternate Text" src="/img/arrow.png">
# </img></div>
# </div>
# <div class="FartChangeInpGroupblock RoomChangeInpGroup">
# <div class="ListFiltTitleBk FartChange">
# <span class="defaultText">ფართი</span>
# <span class="fartValue"></span>
# <img alt="Alternate Text" src="/img/arrow.png">
# </img></div>
# <div class="price_Range_block range-block filter_window area_window" id="rangeBlock">
# <div class="mobile_titles">
# <h3>ფართი</h3>
# <button class="closeWindow" type="button"></button>
# </div>
# <div class="inputs">
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="QuantityFrom" min="0" name="QuantityFrom" placeholder="დან" type="number" value=""/>
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="QuantityTo" min="0" name="QuantityTo" placeholder="მდე" type="number" value=""/>
# </div>
# <div class="item rooms">
# <h3>ოთახები</h3>
# <div class="wrap">
# <input id="Filter_OneRoom" name="Rooms" type="checkbox" value="1"/>
# <label for="Filter_OneRoom">1</label>
# <input id="Filter_TwoRoom" name="Rooms" type="checkbox" value="2"/>
# <label for="Filter_TwoRoom">2</label>
# <input id="Filter_ThreeRoom" name="Rooms" type="checkbox" value="3"/>
# <label for="Filter_ThreeRoom">3</label>
# <input id="Filter_FourRoom" name="Rooms" type="checkbox" value="4"/>
# <label for="Filter_FourRoom">4</label>
# <input id="Filter_Five" name="Rooms" type="checkbox" value="5"/>
# <label for="Filter_Five">5</label>
# <input id="Filter_SixPlusRoom" name="Rooms" type="checkbox" value="6"/>
# <label for="Filter_SixPlusRoom">6+</label>
# </div>
# </div>
# <div class="clean-filter clearFartVal controls">
# <div class="FartClearInput clear">გასუფთავება</div>
# <button class="btn save" type="button">შენახვა</button>
# </div>
# </div>
# </div>
# <div class="FartChangeInpGroupblock price_Range_block">
# <div class="ListFiltTitleBk PriceCurrenyChange">
# <span class="PriceTiTleFilt">ფასი</span>
# <span class="PriceTiTleFiltText"></span>
# <img alt="Alternate Text" src="/img/arrow.png">
# </img></div>
# <div class="price-range price_window filter_window" id="PriceRangeBlock">
# <div class="mobile_titles">
# <h3>ფასი</h3>
# <button class="closeWindow" type="button"></button>
# </div>
# <span class="PriceChecsRg">
# <span class="WholeSpprs">
# <input checked="checked" data-val="true" data-val-required="The PriceType field is required." id="PriceType_Whole" name="PriceType" type="radio" value="false">
# <label for="PriceType_Whole">სრული</label>
# </input></span>
# <input id="PriceType_M" name="PriceType" type="radio" value="true">
# <label for="PriceType_M">m²-ის</label>
# <div class="price_currecny_select filt-cur-select">
# <input data-text="$" id="CurrencyId2" name="CurrencyId" type="radio" value="2"/>
# <label for="CurrencyId2">$</label>
# <input checked="checked" data-text="l" id="CurrencyId1" name="CurrencyId" type="radio" value="1"/>
# <label for="CurrencyId1">l</label>
# </div>
# </input></span>
# <div class="inputs">
# <input id="PriceFrom" min="0" name="PriceFrom" placeholder="დან" type="number" value=""/>
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="PriceTo" min="0" name="PriceTo" placeholder="მდე" type="number" value=""/>
# </div>
# <div class="clean-filter clearPrice controls">
# <div class="PriceClearInput clear">გასუფთავება</div>
# <button class="btn save" type="button">შენახვა</button>
# </div>
# </div>
# </div>
# </div>
# <div class="filters_bottom">
# <div class="new-search">
# <div class="search_group" data-base-url="/ka/udzravi-qoneba/l?Length=10" data-partial-url="/ka/udzravi-qoneba/realestateapplicationlist?Length=10" data-url="/ka/udzravi-qoneba/l?Length=10" id="searchRealEstate" style="display:block!important;">
# <div id="imaginary_container">
# <div class="stylish-input-group input-append">
# <span class="glyphicon glyphicon-search"></span>
# <input autocomplete="off" class="form-control" data-val="true" data-val-required="The StringValues field is required." id="query" name="Context.Request.Query[Query]" placeholder="იპოვეთ სიტყვით,ტელეფონით, ID..." title="შეიყვანეთ მინიმუმ 3 სიმბოლო" type="text" value=""/>
# </div>
# </div>
# </div>
# </div>
# <div class="filters_bottom_left">
# <div class="filters_checkboxes">
# <div class="Checks360Pt">
# <input data-val="true" data-val-required="The WIth360Image field is required." id="WIth360Image" name="WIth360Image" type="checkbox" value="true"/>
# <label for="WIth360Image">გადამოწმებული</label>
# </div>
# <div class="Checks360Pt">
# <input data-val="true" data-val-required="The IsConstruction field is required." id="IsConstruction" name="IsConstruction" type="checkbox" value="true"/>
# <label for="IsConstruction">მხოლოდ დეველოპერის</label>
# </div>
# <div class="filterCheckboxes">
# <input data-val="true" data-val-required="The WithImageOnly field is required." id="WithImageOnly" name="WithImageOnly" type="checkbox" value="true"/>
# <label for="WithImageOnly">სურათით</label>
# </div>
# <div class="filterCheckboxes">
# <input data-val="true" data-val-required="The IndividualEntityOnly field is required." id="IndividualEntityOnly" name="IndividualEntityOnly" type="checkbox" value="true"/>
# <label for="IndividualEntityOnly">მხოლოდ მესაკუთრის</label>
# </div>
# </div>
# </div>
# <div class="filters_bottom_right">
# <div class="advanced_search">
# <a data-toggle="modal" disabled="disabled" href="#advanced_filter" id="advanced_search_button">+ვრცელი ძიება <span id="selected-advanced-fields-count"></span></a>
# </div>
# <div class="SavedFilterBlock">
# </div>
# <div class="search_button">
# <button id="search" type="button">
#                                             იპოვე
#                                         </button>
# </div>
# <div class="SAvedNotification">
# <div class="SAvedNotification_in">
#                                             ძიების შესანახად აირჩიეთ მინიმუმ 5 კომბინაცია
#                                         </div>
# </div>
# </div>
# <button id="clearTopForm" style="display:none;">clearFilter</button>
# </div>
# <div class="cls"></div>
# </div>
# <div aria-hidden="true" class="modal realestate-advanced-filter" data-form="6" data-has-quantity="true" data-has-rooms="false" data-url="/ka/udzravi-qoneba/listfilteradvanced" id="advanced_filter" role="dialog" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal_header_wrap">
# <div class="modal-Header">
# <h2>ვრცელი ძიება</h2>
# <button data-dismiss="modal" onclick="closeLocationModal()" type="button"></button>
# </div>
# </div>
# <div class="modal-body">
# <h3>სართულის ტიპი</h3>
# <div class="NewFilterChecks" data-id="3">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_3__FieldId" name="Fields[3].FieldId" type="hidden" value="151"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_3__Type" name="Fields[3].Type" type="hidden" value="SingleSelect"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_3__StandardField" name="Fields[3].StandardField" type="hidden" value="None"/>
# <div class="item" data-id="409">
# <input class="advancedFilterCheckbox" id="field409" name="Fields[3].SelectedValues" type="checkbox" value="409">
# <span class="checkmark"></span>
# <label for="field409">დუპლექსი</label>
# </input></div>
# <div class="item" data-id="410">
# <input class="advancedFilterCheckbox" id="field410" name="Fields[3].SelectedValues" type="checkbox" value="410">
# <span class="checkmark"></span>
# <label for="field410">ტრიპლექსი</label>
# </input></div>
# <div class="item" data-id="411">
# <input class="advancedFilterCheckbox" id="field411" name="Fields[3].SelectedValues" type="checkbox" value="411">
# <span class="checkmark"></span>
# <label for="field411">სხვენი</label>
# </input></div>
# <div class="item" data-id="527">
# <input class="advancedFilterCheckbox" id="field527" name="Fields[3].SelectedValues" type="checkbox" value="527">
# <span class="checkmark"></span>
# <label for="field527">მილები </label>
# </input></div>
# </div>
# <h3>აივანი/ლოჯია</h3>
# <div class="NewFilterChecks" data-id="4">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_4__FieldId" name="Fields[4].FieldId" type="hidden" value="150"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_4__Type" name="Fields[4].Type" type="hidden" value="SingleSelect"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_4__StandardField" name="Fields[4].StandardField" type="hidden" value="None"/>
# <div class="item" data-id="412">
# <input class="advancedFilterCheckbox" id="field412" name="Fields[4].SelectedValues" type="checkbox" value="412">
# <span class="checkmark"></span>
# <label for="field412">1</label>
# </input></div>
# <div class="item" data-id="413">
# <input class="advancedFilterCheckbox" id="field413" name="Fields[4].SelectedValues" type="checkbox" value="413">
# <span class="checkmark"></span>
# <label for="field413">2</label>
# </input></div>
# <div class="item" data-id="414">
# <input class="advancedFilterCheckbox" id="field414" name="Fields[4].SelectedValues" type="checkbox" value="414">
# <span class="checkmark"></span>
# <label for="field414">3</label>
# </input></div>
# <div class="item" data-id="415">
# <input class="advancedFilterCheckbox" id="field415" name="Fields[4].SelectedValues" type="checkbox" value="415">
# <span class="checkmark"></span>
# <label for="field415">4</label>
# </input></div>
# <div class="item" data-id="416">
# <input class="advancedFilterCheckbox" id="field416" name="Fields[4].SelectedValues" type="checkbox" value="416">
# <span class="checkmark"></span>
# <label for="field416">5</label>
# </input></div>
# <div class="item" data-id="417">
# <input class="advancedFilterCheckbox" id="field417" name="Fields[4].SelectedValues" type="checkbox" value="417">
# <span class="checkmark"></span>
# <label for="field417">არ აქვს</label>
# </input></div>
# </div>
# <h3>სველი წერტილი</h3>
# <div class="NewFilterChecks" data-id="5">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_5__FieldId" name="Fields[5].FieldId" type="hidden" value="152"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_5__Type" name="Fields[5].Type" type="hidden" value="SingleSelect"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_5__StandardField" name="Fields[5].StandardField" type="hidden" value="None"/>
# <div class="item" data-id="418">
# <input class="advancedFilterCheckbox" id="field418" name="Fields[5].SelectedValues" type="checkbox" value="418">
# <span class="checkmark"></span>
# <label for="field418">1</label>
# </input></div>
# <div class="item" data-id="419">
# <input class="advancedFilterCheckbox" id="field419" name="Fields[5].SelectedValues" type="checkbox" value="419">
# <span class="checkmark"></span>
# <label for="field419">2</label>
# </input></div>
# <div class="item" data-id="420">
# <input class="advancedFilterCheckbox" id="field420" name="Fields[5].SelectedValues" type="checkbox" value="420">
# <span class="checkmark"></span>
# <label for="field420">3</label>
# </input></div>
# <div class="item" data-id="421">
# <input class="advancedFilterCheckbox" id="field421" name="Fields[5].SelectedValues" type="checkbox" value="421">
# <span class="checkmark"></span>
# <label for="field421">4</label>
# </input></div>
# <div class="item" data-id="422">
# <input class="advancedFilterCheckbox" id="field422" name="Fields[5].SelectedValues" type="checkbox" value="422">
# <span class="checkmark"></span>
# <label for="field422">5+</label>
# </input></div>
# <div class="item" data-id="423">
# <input class="advancedFilterCheckbox" id="field423" name="Fields[5].SelectedValues" type="checkbox" value="423">
# <span class="checkmark"></span>
# <label for="field423">არ აქვს</label>
# </input></div>
# </div>
# <h3>პროექტი</h3>
# <div class="NewFilterChecks" data-id="6">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_6__FieldId" name="Fields[6].FieldId" type="hidden" value="29"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_6__Type" name="Fields[6].Type" type="hidden" value="SingleSelect"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_6__StandardField" name="Fields[6].StandardField" type="hidden" value="None"/>
# <div class="item" data-id="4">
# <input class="advancedFilterCheckbox" id="field4" name="Fields[6].SelectedValues" type="checkbox" value="4">
# <span class="checkmark"></span>
# <label for="field4">არასტანდარტული</label>
# </input></div>
# <div class="item" data-id="18">
# <input class="advancedFilterCheckbox" id="field18" name="Fields[6].SelectedValues" type="checkbox" value="18">
# <span class="checkmark"></span>
# <label for="field18">ლვოვის</label>
# </input></div>
# <div class="item" data-id="36">
# <input class="advancedFilterCheckbox" id="field36" name="Fields[6].SelectedValues" type="checkbox" value="36">
# <span class="checkmark"></span>
# <label for="field36">იუგოსლავიის</label>
# </input></div>
# <div class="item" data-id="5">
# <input class="advancedFilterCheckbox" id="field5" name="Fields[6].SelectedValues" type="checkbox" value="5">
# <span class="checkmark"></span>
# <label for="field5">ყავლაშვილის</label>
# </input></div>
# <div class="item" data-id="29">
# <input class="advancedFilterCheckbox" id="field29" name="Fields[6].SelectedValues" type="checkbox" value="29">
# <span class="checkmark"></span>
# <label for="field29">თუხარელის</label>
# </input></div>
# <div class="item" data-id="28">
# <input class="advancedFilterCheckbox" id="field28" name="Fields[6].SelectedValues" type="checkbox" value="28">
# <span class="checkmark"></span>
# <label for="field28">ხრუშჩოვის</label>
# </input></div>
# <div class="item" data-id="27">
# <input class="advancedFilterCheckbox" id="field27" name="Fields[6].SelectedValues" type="checkbox" value="27">
# <span class="checkmark"></span>
# <label for="field27">ჩეხური</label>
# </input></div>
# <div class="item" data-id="26">
# <input class="advancedFilterCheckbox" id="field26" name="Fields[6].SelectedValues" type="checkbox" value="26">
# <span class="checkmark"></span>
# <label for="field26">ქალაქური</label>
# </input></div>
# <div class="item" data-id="25">
# <input class="advancedFilterCheckbox" id="field25" name="Fields[6].SelectedValues" type="checkbox" value="25">
# <span class="checkmark"></span>
# <label for="field25">მოსკოვის</label>
# </input></div>
# <div class="item" data-id="20">
# <input class="advancedFilterCheckbox" id="field20" name="Fields[6].SelectedValues" type="checkbox" value="20">
# <span class="checkmark"></span>
# <label for="field20">თბილისური ეზო</label>
# </input></div>
# <div class="item" data-id="30">
# <input class="advancedFilterCheckbox" id="field30" name="Fields[6].SelectedValues" type="checkbox" value="30">
# <span class="checkmark"></span>
# <label for="field30">ვეძისი</label>
# </input></div>
# <div class="item" data-id="19">
# <input class="advancedFilterCheckbox" id="field19" name="Fields[6].SelectedValues" type="checkbox" value="19"/>
# <span class="checkmark"></span>
# <label for="field19">კიევი</label>
# </div>
# <div class="item" data-id="17">
# <input class="advancedFilterCheckbox" id="field17" name="Fields[6].SelectedValues" type="checkbox" value="17"/>
# <span class="checkmark"></span>
# <label for="field17">ლენინგრადის</label>
# </div>
# <div class="item" data-id="38">
# <input class="advancedFilterCheckbox" id="field38" name="Fields[6].SelectedValues" type="checkbox" value="38"/>
# <span class="checkmark"></span>
# <label for="field38">მეტრომშენის</label>
# </div>
# </div>
# <h3>სხვა ინფორმაცია</h3>
# <div class="NewFilterChecks" data-id="7">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_7__FieldId" name="Fields[7].FieldId" type="hidden" value="153"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_7__Type" name="Fields[7].Type" type="hidden" value="MultiSelect"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_7__StandardField" name="Fields[7].StandardField" type="hidden" value="None"/>
# <div class="item" data-id="425">
# <input class="advancedFilterCheckbox" id="field425" name="Fields[7].SelectedValues" type="checkbox" value="425">
# <span class="checkmark"></span>
# <label for="field425">ხედი ეზოზე</label>
# </input></div>
# <div class="item" data-id="426">
# <input class="advancedFilterCheckbox" id="field426" name="Fields[7].SelectedValues" type="checkbox" value="426">
# <span class="checkmark"></span>
# <label for="field426">ხედი ქუჩაზე</label>
# </input></div>
# <div class="item" data-id="427">
# <input class="advancedFilterCheckbox" id="field427" name="Fields[7].SelectedValues" type="checkbox" value="427">
# <span class="checkmark"></span>
# <label for="field427">ნათელი</label>
# </input></div>
# <div class="item" data-id="428">
# <input class="advancedFilterCheckbox" id="field428" name="Fields[7].SelectedValues" type="checkbox" value="428"/>
# <span class="checkmark"></span>
# <label for="field428">მყუდრო</label>
# </div>
# </div>
# <h3>მდგომარეობა</h3>
# <div class="NewFilterChecks" data-id="8">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_8__FieldId" name="Fields[8].FieldId" type="hidden" value="30"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_8__Type" name="Fields[8].Type" type="hidden" value="SingleSelect"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_8__StandardField" name="Fields[8].StandardField" type="hidden" value="None"/>
# <div class="item" data-id="16">
# <input class="advancedFilterCheckbox" id="field16" name="Fields[8].SelectedValues" type="checkbox" value="16">
# <span class="checkmark"></span>
# <label for="field16">ახალი რემონტით</label>
# </input></div>
# <div class="item" data-id="15">
# <input class="advancedFilterCheckbox" id="field15" name="Fields[8].SelectedValues" type="checkbox" value="15">
# <span class="checkmark"></span>
# <label for="field15">გარემონტებული</label>
# </input></div>
# <div class="item" data-id="12">
# <input class="advancedFilterCheckbox" id="field12" name="Fields[8].SelectedValues" type="checkbox" value="12">
# <span class="checkmark"></span>
# <label for="field12">ძველი რემონტით</label>
# </input></div>
# <div class="item" data-id="11">
# <input class="advancedFilterCheckbox" id="field11" name="Fields[8].SelectedValues" type="checkbox" value="11"/>
# <span class="checkmark"></span>
# <label for="field11">მიმდინარე რემონტი</label>
# </div>
# <div class="item" data-id="10">
# <input class="advancedFilterCheckbox" id="field10" name="Fields[8].SelectedValues" type="checkbox" value="10"/>
# <span class="checkmark"></span>
# <label for="field10">სარემონტო</label>
# </div>
# <div class="item" data-id="8">
# <input class="advancedFilterCheckbox" id="field8" name="Fields[8].SelectedValues" type="checkbox" value="8"/>
# <span class="checkmark"></span>
# <label for="field8">შავი კარკასი</label>
# </div>
# <div class="item" data-id="9">
# <input class="advancedFilterCheckbox" id="field9" name="Fields[8].SelectedValues" type="checkbox" value="9"/>
# <span class="checkmark"></span>
# <label for="field9">თეთრი კარკასი</label>
# </div>
# <div class="item" data-id="35">
# <input class="advancedFilterCheckbox" id="field35" name="Fields[8].SelectedValues" type="checkbox" value="35"/>
# <span class="checkmark"></span>
# <label for="field35">მწვანე კარკასი</label>
# </div>
# </div>
# <div style="display: flex;justify-content: space-between;flex-wrap: wrap">
# <div class="text_inputs">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_0__FieldId" name="Fields[0].FieldId" type="hidden" value="48"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_0__Type" name="Fields[0].Type" type="hidden" value="Number"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_0__StandardField" name="Fields[0].StandardField" type="hidden" value="None"/>
# <div class="item">
# <h3> საძინებლები</h3>
# <div>
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="Fields_0__ValueFrom" name="Fields[0].ValueFrom" placeholder="დან" type="number" value="">
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="Fields_0__ValueTo" name="Fields[0].ValueTo" placeholder="მდე" type="number" value="">
# </input></input></div>
# </div>
# </div>
# <div class="text_inputs">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_1__FieldId" name="Fields[1].FieldId" type="hidden" value="146"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_1__Type" name="Fields[1].Type" type="hidden" value="Number"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_1__StandardField" name="Fields[1].StandardField" type="hidden" value="None"/>
# <div class="item">
# <h3> სამზარეულოს ფართი</h3>
# <div>
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="Fields_1__ValueFrom" name="Fields[1].ValueFrom" placeholder="დან" type="number" value="">
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="Fields_1__ValueTo" name="Fields[1].ValueTo" placeholder="მდე" type="number" value="">
# </input></input></div>
# </div>
# </div>
# <div class="text_inputs">
# <input constant="" data-val="true" data-val-required="The FieldId field is required." id="Fields_2__FieldId" name="Fields[2].FieldId" type="hidden" value="28"/>
# <input constant="" data-val="true" data-val-required="The Type field is required." id="Fields_2__Type" name="Fields[2].Type" type="hidden" value="Number"/>
# <input constant="" data-val="true" data-val-required="The StandardField field is required." id="Fields_2__StandardField" name="Fields[2].StandardField" type="hidden" value="Floor"/>
# <div class="item">
# <h3> სართული</h3>
# <div>
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="Fields_2__ValueFrom" name="Fields[2].ValueFrom" placeholder="დან" type="number" value="">
# <input data-val="true" data-val-number="{0} ველი უნდა იყოს რიცხვი" id="Fields_2__ValueTo" name="Fields[2].ValueTo" placeholder="მდე" type="number" value="">
# </input></input></div>
# </div>
# </div>
# </div>
# <div class="extra_info">
# <h3>დამატებითი ინფორმაცია</h3>
# <div class="wrap row">
# <input data-val="true" data-val-required="The FieldId field is required." id="Fields_9__FieldId" name="Fields[9].FieldId" type="hidden" value="14"/>
# <input data-val="true" data-val-required="The Type field is required." id="Fields_9__Type" name="Fields[9].Type" type="hidden" value="Group"/>
# <input data-val="true" data-val-required="The StandardField field is required." id="Fields_9__StandardField" name="Fields[9].StandardField" type="hidden" value="None"/>
# <div class="col-lg-3">
# <input id="Fields_9__Values_0__Value" name="Fields[9].Values[0].Value" type="hidden" value="35">
# <div class="item">
# <input data-val="true" data-val-required="The Selected field is required." id="Field14_35" name="Fields[9].Values[0].Selected" type="checkbox" value="true">
# <label for="Field14_35">ცენტრალური გათბობა</label>
# </input></div>
# </input></div>
# <div class="col-lg-3">
# <input id="Fields_9__Values_1__Value" name="Fields[9].Values[1].Value" type="hidden" value="36">
# <div class="item">
# <input data-val="true" data-val-required="The Selected field is required." id="Field14_36" name="Fields[9].Values[1].Selected" type="checkbox" value="true">
# <label for="Field14_36">ბუნებრივი აირი</label>
# </input></div>
# </input></div>
# <div class="col-lg-3">
# <input id="Fields_9__Values_2__Value" name="Fields[9].Values[2].Value" type="hidden" value="37">
# <div class="item">
# ...
#         //    $('.cityText').html(cityElement.attr('title'));
#         //    $('.default-value').hide();
#         //    if (cityValue.length > 1) {
#         //        $('.default-value').hide();
#         //    } else {
#         //        $('.default-value').show();
#         //        $('.cityText').html("");
#         //    }
#         //if (cityValue == 95) {
#         //    populateSds(filteredSdArray);
#         //    $('.dtlTabs').removeClass('disabled');
#         //}
#         //var currencyValue = $('#PrcSource').val();
#         //if (currencyValue.length > 0) {
#
#         //    $('.filt-cur-select input[value=' + currencyValue + ']').prop("checked", true);
#         //}
#
#
#         //$('.filt-cur-select input').click(function () {
#         //    $('#PrcSource').val($(this).val())
#
#         //});
#
#
#             //var sdItemHtml = ""
#             //selectedSd.forEach(function (e, i) {
#
#             //    $('.sdItem[data-value="' + e + '"]').addClass('active');
#             //    sdItemHtml += "," + $('.sdItem[data-value="' + e + '"]').attr('title');
#
#             //});
#             //$('.locationMultiSelect .subDistrText').html(sdItemHtml)
#             //$(".count-sdItem-items").html("(" + $('.sdItem.active').length + ")");
#             //if ($("#subdistr").val().length > 0) {
#             //    $('.dtlTabsStr').removeClass('disabled');
#             //}
#         //populateStreets(filteredStrArray);
#
#         //var stValue = $("#stId").val();
#         //selectedStr = stValue.split(",");
#         //    selectedStr = _.map(_.filter(selectedStr, function (val1) { return val1.length > 0 }), function (val) { return parseInt(val) });
#         //    var selectedStrHtml = "";
#         //    selectedStr.forEach(function (e, i) {
#         //        selectedStrHtml += "," + $('.strItem[data-value="' + e + '"]').attr('title');
#         //    $('.strItem[data-value="' + e + '"]').addClass('active');
#         //    });
#         //    $('.strText').html(selectedStrHtml);
#         //     $(".count-str-items").html("(" + $('.strItem.active').length + ")");
#
#         //    var dsValue = $('#SDs').val();
#         //    selecteddistr = dsValue.split(",");
#         //    selecteddistr = _.map(selecteddistr, function (val) {
#         //        return parseInt(val)
#         //    });
#         //    selecteddistr.forEach(function (e, i) {
#         //        $('.dItem[data-value="' + e + '"]').addClass('active');
#         //    });
#             $('.dItem').each(function () {
#                 var pVal = $(this).data('value')
#                 if ($('.sdItem.active[data-parent="' + pVal + '"]').length >= $('.sdItem[data-parent="' + pVal + '"]').length) {
#                     $('.dItem[data-value="' + pVal + '"]').addClass('active');
#                 }
#                 })
#
#             $(document).ready(function () {
#                 if ($(window).width() < 770) {
#                    // $('html,body').scrollTo($(".latest_articles_block"), { duration: 300, offset: -30 })
#                 }
#                 if ($('input[name="RealEstateTypeId"]').is(":checked") > 0 && $('#RealEstateDealTypeId').val().length>0){
#                     $('#advanced_search_button').removeAttr('disabled').prop('disabled', false);
#                 }
#
#             });
#             if (($('#QuantityFrom').val().length >= 1 || $('#QuantityTo').val() >= 1) && $("#RoomsCount").val().length > 0) {
#                 $('.fartValue').html( $('#QuantityFrom').val() + " - " + $('#QuantityTo').val() + " m², " + $("#RoomsCount").val() + " ოთახიანი")
#                 $('.defaultText').hide();
#
#             } else if ($('#QuantityFrom').val().length >= 1 || $('#QuantityTo').val() >= 1 && $("#RoomsCount").val().length == 0) {
#                 $('.fartValue').html($('#QuantityFrom').val() + " - " + $('#QuantityTo').val() + " m²");
#                 $('.defaultText').hide();
#             } else if ($('#QuantityFrom').val().length <= 1 && $('#QuantityTo').val() <= 1 && $("#RoomsCount").val().length > 0) {
#                 $('.fartValue').html($("#RoomsCount").val() + " ოთახიანი");
#                 $('.defaultText').hide();
#             }
#             else {
#                 $('.FartChange .defaultText').show();
#             }
#
#         if ($('#PriceFrom').val().length >=1 || $('#PriceTo').val().length >=1) {
#             $('.PriceTiTleFilt').hide();
#             if (!$('.filt-cur-select input[type=radio]').is(':checked')) {
#                 $('.PriceTiTleFiltText').html($('#PriceFrom').val() + " - " + $('#PriceTo').val());
#             } else {
#                 $('.PriceTiTleFiltText').html($('#PriceFrom').val() + " - " + $('#PriceTo').val() + " " + "<span class='valute'>" + $('.price_currecny_select input[type=radio]:checked').data('text') + "</span>");
#             }
#
#         }
#         else {
#             $('.PriceTiTleFilt').show();
#             //$("#CurrencyId1").prop("checked", true);
#         }
#
#           if ($(window).width() < 761) {
#             $('#StreetCountSelectmult,#RoomsCountSelectmult').SumoSelect({
#                 search: false,
#                 triggerChangeCombined: true,
#
#                 forceCustomRendering: true,
#                 captionFormat: 'არჩეულია {0}',
#                 captionFormatAllSelected: 'ყველა არჩეულია',
#                 locale: ['არჩევა', 'დახურვა', 'ყველას არჩევა'],
#             }, options);
#
#         }
#         else {
#             $('#StreetCountSelectmult,#RoomsCountSelectmult').SumoSelect({
#                 search: true,
#                 triggerChangeCombined: true,
#                 forceCustomRendering: true,
#                   searchText: 'ძიება...',
#                 tch: 'შედეგი არ მოიძებნა "{0}"',
#                 captionFormat: 'არჩეულია {0}',
#                 captionFormatAllSelected: 'ყველა არჩეულია',
#                 locale: ['არჩევა', 'დახურვა', 'ყველას არჩევა'],
#             }, options);
#
#         }
#         $('select[multiple]').SumoSelect({
#
#                      forceCustomRendering:true,
#                      triggerChangeCombined: true,
#                      captionFormat: 'არჩეულია {0}',
#                      captionFormatAllSelected: 'ყველა არჩეულია',
#                      locale: ['არჩევა', 'დახურვა', 'ყველას არჩევა'],
#         }, options);
#
#          $('#advanced_search_button').on('click', function (e) {
#              $(".selectpicker").selectpicker();
#
#             $('.search_advanced').animate({ height: 'toggle' });
#
#            // $('.all_page_blocks_overlay').toggleClass('all_page_blocks_overlay_bg');
#             $('select[multiple]').SumoSelect({
#                      forceCustomRendering:true,
#                      triggerChangeCombined: true,
#                      captionFormat: 'არჩეულია {0}',
#                      captionFormatAllSelected: 'ყველა არჩეულია',
#                      locale: ['არჩევა', 'დახურვა', 'ყველას არჩევა'],
#             }, options);
#
#             if ($('#advanced_search_button_hide').length) {
#                 $(this).hide();
#                 $('#advanced_search_button_hide').parent().show();
#             }
#         });
#
#
#
#         //$(document).off( '#nav_filters input[type="checkbox"]:not([multiple])');
#
#         </script>
# <script type="text/javascript">
#     $(function () {
#         if ($('div#title').text() != '')
#             document.title = $('div#title').text();
#         $('#UserApplicationCount').text('0');
#     })
#     </script>
# <script>
#         //if ($('.selectedFilter').length >= 3) {
#         //    $('#renewFiltreBtn').removeAttr('disabled');
#         //}
#
#
#
#     </script>
# <script src="https://cdn.jsdelivr.net/npm/bootstrap-select@1.13.14/dist/js/bootstrap-select.min.js"></script>
# <script src="/js/mobile-filter.min.js?v=jNp_-9EigSlmx76f4cnzEbQ4RrAmagOndAUM3lWko3I"></script>
# <script src="/js/save-filter.min.js?v=jrwRJblw3CoQhUR7ulmx3uUkex4T_tifr2Ean11ekX4"></script>
# <script src="/js/filter-advanced.min.js?v=L4ouBrQRDJhr1D6O-3acuI6IGcQpdCWUkTpEESQV904"></script>
# <script src="https://unpkg.com/infinite-scroll@3/dist/infinite-scroll.pkgd.min.js"></script>
# <script src="/js/newspaper.min.js?v=oaWB_Pa_kz_UhvLeRGsSrUEoop4PWhsGFaZmtCYvK60"></script>
# <script>
#
#         $('#renewFiltreBtn').on('click', function () {
#
#             if ($('#renewFiltreBtn').attr('disabled') != 'disabled') {
#                 if ($('#UserEmail').val().length > 7) {
#                     $('#selectmaildays').removeAttr('disabled');
#                     $('#selectmaildays')[0].sumo.reload();
#                     $('#mailnotificationfilter').removeAttr('disabled');
#                 }
#                 else {
#                     $('#UserEmail').removeAttr('disabled');
#                 }
#                 //GetFilterNamesDefault();
#             }
#             else {
#
#                 e.preventDefault();
#             }
#         });
#
#         $('#subscribe_post .subscribe_post_msg .close_msg').click(function () {
#             $('.subscribe_post_msg').hide();
#         });
#
#         $('.SelectMailDaysBox').SumoSelect();
#
#
#         var RealEstateDealTypeIdVal = $("#RealEstateDealTypeId").val()
#         if (RealEstateDealTypeIdVal.length > 0) {
#             var dealTypeTitle = $(".realEstateDealTypeList li[data-value='" + RealEstateDealTypeIdVal + "']").attr("title");
#             var dealTypeSeoTitle = $(".realEstateDealTypeList li[data-value='" + RealEstateDealTypeIdVal + "']").attr("data-seo");
#             $("#RealEstateDealTypeId").attr("seo", dealTypeSeoTitle);
#             $(".realEstateDealTypeList li[data-value='" + RealEstateDealTypeIdVal + "']").addClass("active")
#             $(".realEstateDealTypeIdBtn span").text(dealTypeTitle)
#         }
#
#         function seenTag() {
#             var arr = $.cookie("viewed-application-ids").split(' ');
#             var arrr = JSON.parse(arr);
#             $.each(arrr, function () {
#                 $('[data-id=' + this + ']').find('.seen-tag').show();
#             });
#         };
#
#         $(document).ready(function () {
#             if ($.cookie("viewed-application-ids") != null) {
#                 seenTag();
#             }
#
#             //$(document).ready(function () {
#             //    closeLocationModal();
#             //});
#
#             if ($('.subDistrText').text() === "") {
#                 $('.cityText').removeClass('showCityIcon');
#             } else {
#                 $('.cityText').addClass('showCityIcon');
#             }
#             $('.dealtypeSelector p').click(function () {
#                 var href = $('.suggestions .item.active').attr('href');
#                 window.location.href = href;
#             });
#
#         });
#         $(document).on("click", ".latest_article_each_in", function () {
#             var scrollPos = window.scrollY;
#             $.cookie('scrollposition', scrollPos, { path: '/' });
#         });
#
#         if ($.cookie("scrollposition")) {
#             var scrollPosition = $.cookie("scrollposition");
#             $('html,body').scrollTo(scrollPosition, { duration: 300, offset: 0 });
#             $.removeCookie("scrollposition", { path: '/' });
#         } else {
#             if ($(window).width() < 770) {
#                 $('html,body').scrollTo($(".latest_article_each"), { duration: 300, offset: 0 });
#             }
#         }
#         //if ($.cookie("ApplicationId")) {
#         //    console.log($.cookie("ApplicationId"))
#         //    var applicationId = $.cookie("ApplicationId");
#         //    $('html,body').scrollTo($('.latest_article_each[data-id="' + applicationId + '"]'), { duration: 300, offset: 0 });
#
#         //    //$.removeCookie("ApplicationId", { path: '/' });
#         //} else {
#         //    if ($(window).width() < 770) {
#         //        $('html,body').scrollTo($(".latest_article_each"), { duration: 300, offset: 0 });
#         //    }
#         //}
#         function SetStorageValue() {
#             var RealEstateType = $('.realestatetypeSelect:checked').next().text();
#             var dealtypeId = $('#RealEstateDealTypeId').val();
#             var DealType = $(".realEstateDealTypeList li[data-value='" + dealtypeId + "']").attr("title");
#             var City = $(".selectedText .cityText").text();
#             var subDistrText = $(".selectedText .subDistrText").text();
#             var strText = $(".selectedText .strText").text();
#             var QuantitiyFrom = $('#QuantityFrom').val();
#             var QuantitiyTo = $('#QuantityTo').val();
#             var Quantity = QuantitiyFrom + '-' + QuantitiyTo + ' M²';
#             var PriceFrom = $('#PriceFrom').val();
#             var PriceTo = $('#PriceTo').val();
#             var valPrice = $('#PrcSource').val();
#             if (valPrice === '1') {
#                 var currency = ' ₾';
#             } else {
#                 var currency = ' $';
#             }
#             var Price = PriceFrom + '-' + PriceTo + '' + currency;
#             var sFilter = [];
#             var sameUrl = false;
#             var storageFilter = JSON.parse(localStorage.getItem('ssfilter'));
#             var currentUrl = window.location.href;
#             if (storageFilter != null) {
#                 storageFilter.forEach(function (e) {
#                     if (e.url !== currentUrl) {
#                         sFilter.push(e);
#                         sameUrl = false;
#                     } else {
#                         sameUrl = true;
#                     }
#                 })
#
#             }
#
#             if (!sameUrl && (RealEstateType.trim().length > 0 || DealType.trim().length > 0 || City.trim().length>0)) {
#                 if (sFilter.length == 3) {
#                     sFilter.shift();
#                 }
#                 sFilter.push({ url: currentUrl, realestatetype: RealEstateType, dealtype: DealType, citytitle: City, subDistrText: subDistrText, strText: strText });
#                 localStorage.setItem('ssfilter', JSON.stringify(sFilter));
#             }
#
#         }
#         window.onload = (event) => {
#             SetStorageValue();
#         };
#
#     //random banner
#
#         var bannerIndex = Math.floor(Math.random() * 3) + 1;
#         console.log(bannerIndex)
#         $('.banner-' + bannerIndex).show();
#
#     </script>
# <script type="text/javascript">
#         var isAuthed = false;
#         var promoUrl =  '/ka/home/promopaidservices';
#             //if (isAuthed) {
#             //    if (window.parent != window && window.parent.location.hostname == window.location.hostname) {
#             //        window.stop();
#             //        window.parent.location = window.location;
#             //    }
#
#             //    if (window.opener && window.opener.parent.location.hostname == window.location.hostname && window.location.pathname != promoUrl ) {
#             //        window.stop();
#             //        window.opener.parent.location = window.location;
#             //        window.close();
#             //    }
#             //}
#
#
#
#     </script>
# <script type="text/javascript">
#         var IsAuth = 'False';
#         $(document).ready(function () {
#
#             if ($.cookie('nyModalHide') == null && $.cookie('nyModalHideForever') == null && IsAuth == 'True') {
#                 $('#NyPopUp').modal();
#             }
#         })
#
#
#         if ($(window).width() < 761) {
#
#             $('#StreetCountSelectmult,#RoomsCountSelectmult').SumoSelect({
#                 search: false,
#                 triggerChangeCombined: true,
#
#                 forceCustomRendering: true,
#                 captionFormat: 'არჩეულია {0}',
#                 captionFormatAllSelected: 'ყველა არჩეულია',
#                 locale: ['არჩევა', 'დახურვა', 'ყველას არჩევა'],
#             }, options);
#
#         }
#         else {
#             $('#StreetCountSelectmult,#RoomsCountSelectmult').SumoSelect({
#
#                 triggerChangeCombined: true,
#                 forceCustomRendering: true,
#                   searchText: 'ძიება...',
#                 tch: 'შედეგი არ მოიძებნა "{0}"',
#                 captionFormat: 'არჩეულია {0}',
#                 captionFormatAllSelected: 'ყველა არჩეულია',
#                 locale: ['არჩევა', 'დახურვა', 'ყველას არჩევა'],
#             }, options);
#
#         }
#         $('#lang,#PriceCurrencyChanger,.PaidServBodyout select').SumoSelect({ search: false, showTitle: false, forceCustomRendering: true });
#
#
#
#     </script>
# </body>
